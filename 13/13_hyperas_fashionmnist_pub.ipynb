# %% [markdown]
# **Copyright**
#
# Jelen forráskód a Budapesti Műszaki és Gazdaságtudományi Egyetemen tartott
# "Deep Learning a gyakorlatban Python és LUA alapon" tantárgy segédanyagaként készült.
#
# A tantárgy honlapja: http://smartlab.tmit.bme.hu/oktatas-deep-learning
# Deep Learning kutatás: http://smartlab.tmit.bme.hu/deep-learning
#
# A forráskódot GPLv3 licensz védi. Újrafelhasználás esetén lehetőség szerint kérjük
# az alábbi szerzőt értesíteni.
#
# 2019 (c) Csapó Tamás Gábor (csapot kukac tmit pont bme pont hu),
# Gyires-Tóth Bálint, Zainkó Csaba
#
# Links:
#
# hiperparaméter optimalizálás, hyperas: https://github.com/maxpumperla/hyperas

# %%
# érdemes előre telepíteni, és utána újraindítani
# !pip3 install hyperas
# !pip3 install hyperopt

# %%
# először készítünk egy egyszerű hálót fashion_mnist osztályozásra

# %%
import keras
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.callbacks import EarlyStopping
import numpy as np
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
batch_size = 32
num_classes = 10
epochs = 100

# %%
# one-hot enkódolttá alakítás
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
# átalakítás FC-DNN-hez
x_train = np.reshape(x_train,(-1,784)) # 28x28
x_test = np.reshape(x_test,(-1,784))
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# normalizálás, [0-1]
x_train /= 255
x_test /= 255

# %%
model = Sequential()
model.add(Dense(256, activation='relu', input_dim=784))
model.add(Dense(256, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='sgd',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
callbacks = [EarlyStopping(monitor='val_acc', patience=3, verbose=0)]

# %%
result = model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              callbacks=callbacks,
              shuffle=True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.7127 - acc: 0.7679 - val_loss: 0.5388 - val_acc: 0.8058
# Epoch 2/100
# 60000/60000 [==============================] - 8s 132us/step - loss: 0.4805 - acc: 0.8324 - val_loss: 0.5109 - val_acc: 0.8203
# Epoch 3/100
# 60000/60000 [==============================] - 8s 133us/step - loss: 0.4372 - acc: 0.8468 - val_loss: 0.4506 - val_acc: 0.8421
# Epoch 4/100
# 60000/60000 [==============================] - 8s 132us/step - loss: 0.4116 - acc: 0.8553 - val_loss: 0.4296 - val_acc: 0.8465
# Epoch 5/100
# 60000/60000 [==============================] - 8s 133us/step - loss: 0.3907 - acc: 0.8620 - val_loss: 0.4176 - val_acc: 0.8528
# Epoch 6/100
# 60000/60000 [==============================] - 8s 129us/step - loss: 0.3760 - acc: 0.8686 - val_loss: 0.4061 - val_acc: 0.8554
# Epoch 7/100
# 60000/60000 [==============================] - 8s 131us/step - loss: 0.3630 - acc: 0.8723 - val_loss: 0.4017 - val_acc: 0.8588
# Epoch 8/100
# 60000/60000 [==============================] - 8s 132us/step - loss: 0.3507 - acc: 0.8759 - val_loss: 0.4078 - val_acc: 0.8544
# Epoch 9/100
# 60000/60000 [==============================] - 8s 130us/step - loss: 0.3408 - acc: 0.8799 - val_loss: 0.3918 - val_acc: 0.8578
# Epoch 10/100
# 60000/60000 [==============================] - 8s 132us/step - loss: 0.3314 - acc: 0.8820 - val_loss: 0.3720 - val_acc: 0.8677
# Epoch 11/100
# 60000/60000 [==============================] - 8s 130us/step - loss: 0.3233 - acc: 0.8849 - val_loss: 0.3660 - val_acc: 0.8670
# Epoch 12/100
# 60000/60000 [==============================] - 8s 130us/step - loss: 0.3163 - acc: 0.8869 - val_loss: 0.3616 - val_acc: 0.8714
# Epoch 13/100
# 60000/60000 [==============================] - 8s 132us/step - loss: 0.3078 - acc: 0.8892 - val_loss: 0.3576 - val_acc: 0.8747
# Epoch 14/100
# 60000/60000 [==============================] - 8s 130us/step - loss: 0.3020 - acc: 0.8914 - val_loss: 0.3633 - val_acc: 0.8664
# Epoch 15/100
# 60000/60000 [==============================] - 8s 132us/step - loss: 0.2963 - acc: 0.8935 - val_loss: 0.3610 - val_acc: 0.8683
# Epoch 16/100
# 60000/60000 [==============================] - 8s 130us/step - loss: 0.2898 - acc: 0.8962 - val_loss: 0.3420 - val_acc: 0.8778
# Epoch 17/100
# 60000/60000 [==============================] - 8s 135us/step - loss: 0.2854 - acc: 0.8974 - val_loss: 0.3451 - val_acc: 0.8760
# Epoch 18/100
# 60000/60000 [==============================] - 8s 132us/step - loss: 0.2794 - acc: 0.8983 - val_loss: 0.3400 - val_acc: 0.8781
# Epoch 19/100
# 60000/60000 [==============================] - 8s 128us/step - loss: 0.2737 - acc: 0.9000 - val_loss: 0.3398 - val_acc: 0.8781
# Epoch 20/100
# 60000/60000 [==============================] - 8s 129us/step - loss: 0.2692 - acc: 0.9028 - val_loss: 0.3530 - val_acc: 0.8734
# Epoch 21/100
# 60000/60000 [==============================] - 8s 130us/step - loss: 0.2635 - acc: 0.9051 - val_loss: 0.3477 - val_acc: 0.8741

# %%
# legnagyobb val_acc háló a tanítások közül
best_val_acc = np.amax(result.history['val_acc']) 
print('legjobb val_acc:', best_val_acc)
# Out:
# legjobb val_acc: 0.8781

# %%
# a következő részben alakítjuk át a hyperas számára megfelelő formátumba,
# amiben a fenti hálózatot egészítjük ki / alakítjuk át:
#  - adatok betöltése megy a data() függvénybe
#  - hálózat definíció, és utána choice-ok, 
#    valamint loggolás a create_model() függvényben
#

# %%
# hyperas -> külön kell választani az adat betöltést és modell készítést

def data():
  (x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
  
  num_classes = 10
  
  # one-hot enkódolttá alakítás
  y_train = keras.utils.to_categorical(y_train, num_classes)
  y_test = keras.utils.to_categorical(y_test, num_classes)
  
  # átalakítás FC-DNN-hez
  x_train = np.reshape(x_train,(-1,784)) # 28x28
  x_test = np.reshape(x_test,(-1,784))
  x_train = x_train.astype('float32')
  x_test = x_test.astype('float32')

  # normalizálás, [0-1]
  x_train /= 255
  x_test /= 255
  
  return x_train, y_train, x_test, y_test

# %%
def create_model(x_train, y_train, x_test, y_test):
    
    # másoljuk ide a swish definícióját:
    # https://stackoverflow.com/questions/53050448/custom-activation-with-parameter
    from keras.layers import Layer
    from keras import backend as K

    class Swish(Layer):
        def __init__(self, beta, **kwargs):
            super(Swish, self).__init__(**kwargs)
            self.beta = K.cast_to_floatx(beta)

        def call(self, inputs):
            return K.sigmoid(self.beta * inputs) * inputs

        def get_config(self):
            config = {'beta': float(self.beta)}
            base_config = super(Swish, self).get_config()
            return dict(list(base_config.items()) + list(config.items()))

        def compute_output_shape(self, input_shape):
            return input_shape
    # eddig tart a swish definíció
    
    # itt kezdődnek az általunk definiált hiperparaméterek,
    # amiket majd a modellbe teszünk bele
    n_layer1 = {{choice([128, 256, 512])}}
    n_layer2 = {{choice([128, 256, 512])}}
    dropout_1 = {{uniform(0, 0.5)}}
    dropout_2 = {{uniform(0, 0.5)}}
    act = {{choice(['relu', 'leakyrelu', 'swish'])}}
    optim = {{choice(['rmsprop', 'adam', 'sgd'])}}
    n_batch = {{choice([64, 128, 256])}}
    print('a modell hiperparaméterei: ', n_layer1, n_layer2, dropout_1, dropout_2, act, optim, n_batch)
    # 3 x 3 x [0-1]x[0-1] x 3 x 3 x 3  = hatalmas paraméter tér
    
    # aktivacio: string -> valtozo
    if act == 'relu':
        activation = keras.layers.ReLU()
    elif act == 'leakyrelu':
        activation = keras.layers.LeakyReLU()
    elif act == 'swish':
        activation = Swish(beta=0.3)
    
    model = Sequential()
    model.add(Dense(n_layer1, input_dim=784))
    model.add(activation)
    model.add(Dropout(dropout_1))
    model.add(Dense(n_layer2))
    model.add(activation)
    model.add(Dropout(dropout_2))
    model.add(Dense(10, activation='softmax'))
    
    model.compile(optimizer=optim,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    callbacks = [EarlyStopping(monitor='val_acc', patience=3, verbose=0)]
    
    result = model.fit(x_train, y_train,
              batch_size=n_batch,
              epochs=100,
              verbose=2,
              validation_data=(x_test, y_test),
              callbacks=callbacks,
              shuffle=True)

    
    # az epoch-ok közül a legnagyobb val_acc elmentése
    best_val_acc = np.amax(result.history['val_acc']) 
    print('legjobb val_acc:', best_val_acc)
    
    # log kiírása: háló struktúra, és az eredmény
    with open('hyperas-fashionmnist-log.csv', 'a') as csv_file:
      csv_file.write(str(n_layer1) + ';')
      csv_file.write(str(n_layer2) + ';')
      csv_file.write(str(dropout_1) + ';')
      csv_file.write(str(dropout_2) + ';')
      csv_file.write(str(act) + ';')
      csv_file.write(str(optim) + ';')
      csv_file.write(str(n_batch) + ';')
      csv_file.write(str(best_val_acc) + '\n')


    # negatív val_acc, mert a hyperopt csomag mindig minimalizál
    return {'loss': -best_val_acc, 'status': STATUS_OK, 'model': model}

# %%
# log fájl inicializálás / fejléc
with open('hyperas-fashionmnist-log.csv', 'w') as csv_file:
  csv_file.write('n_layer1' + ';')
  csv_file.write('n_layer2' + ';')
  csv_file.write('dropout_1' + ';')
  csv_file.write('dropout_2' + ';')
  csv_file.write('act' + ';')
  csv_file.write('optim' + ';')
  csv_file.write('n_batch' + ';')
  csv_file.write('best_val_acc' + '\n')

# %%
# ezután colab-ról le kell tölteni a notebook-ot
# és a .ipynb fájlt utána visszatölteni az aktuális könyvtárba

# %%
# hyperas-hoz kapcsolódó importok
import hyperas
from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import choice, uniform

# %%
# teljes hiperparaméter optimalizálás indítása
best_run, best_model = optim.minimize(model=create_model,
                                          data=data,
                                          algo=tpe.suggest,
                                          max_evals=5,
                                          notebook_name='13_hyperas_fashionmnist_pub',
                                          trials=Trials())
# Out:
# >>> Imports:
# #coding=utf-8
#
# try:
#     import keras
# except:
#     pass
#
# try:
#     from keras.datasets import fashion_mnist
# except:
#     pass
#
# try:
#     from keras.models import Sequential
# except:
#     pass
#
# try:
#     from keras.layers import Dense, Dropout, Activation
# except:
#     pass
#
# try:
#     from keras.callbacks import EarlyStopping
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     from keras.layers import Layer
# except:
#     pass
#
# try:
#     from keras import backend as K
# except:
#     pass
#
# try:
#     import hyperas
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform
# except:
#     pass
#
# try:
#     import pandas
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'n_layer1': hp.choice('n_layer1', [128, 256, 512]),
#         'n_layer1_1': hp.choice('n_layer1_1', [128, 256, 512]),
#         'dropout_1': hp.uniform('dropout_1', 0, 0.5),
#         'dropout_1_1': hp.uniform('dropout_1_1', 0, 0.5),
#         'act': hp.choice('act', ['relu', 'leakyrelu', 'swish']),
#         'optim': hp.choice('optim', ['rmsprop', 'adam', 'sgd']),
#         'n_batch': hp.choice('n_batch', [64, 128, 256]),
#     }
#
# >>> Data
#   1:
#   2: (x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
#   3:
#   4: num_classes = 10
#   5:
#   6: # one-hot enkódolttá alakítás
#   7: y_train = keras.utils.to_categorical(y_train, num_classes)
#   8: y_test = keras.utils.to_categorical(y_test, num_classes)
#   9:
#  10: # átalakítás FC-DNN-hez
#  11: x_train = np.reshape(x_train,(-1,784)) # 28x28
#  12: x_test = np.reshape(x_test,(-1,784))
#  13: x_train = x_train.astype('float32')
#  14: x_test = x_test.astype('float32')
#  15:
#  16: # normalizálás, [0-1]
#  17: x_train /= 255
#  18: x_test /= 255
#  19:
#  20:
#  21:
#  22:
# >>> Resulting replaced keras model:
#
#    1: def keras_fmin_fnct(space):
#    2:
#    3:
#    4:     # másoljuk ide a swish definícióját:
#    5:     # https://stackoverflow.com/questions/53050448/custom-activation-with-parameter
#    6:
#    7:     class Swish(Layer):
#    8:         def __init__(self, beta, **kwargs):
#    9:             super(Swish, self).__init__(**kwargs)
#   10:             self.beta = K.cast_to_floatx(beta)
#   11:
#   12:         def call(self, inputs):
#   13:             return K.sigmoid(self.beta * inputs) * inputs
#   14:
#   15:         def get_config(self):
#   16:             config = {'beta': float(self.beta)}
#   17:             base_config = super(Swish, self).get_config()
#   18:             return dict(list(base_config.items()) + list(config.items()))
#   19:
#   20:         def compute_output_shape(self, input_shape):
#   21:             return input_shape
#   22:     # eddig tart a swish definíció
#   23:
#   24:     # itt kezdődnek az általunk definiált hiperparaméterek,
#   25:     # amiket majd a modellbe teszünk bele
#   26:     n_layer1 = space['n_layer1']
#   27:     n_layer2 = space['n_layer1_1']
#   28:     dropout_1 = space['dropout_1']
#   29:     dropout_2 = space['dropout_1_1']
#   30:     act = space['act']
#   31:     optim = space['optim']
#   32:     n_batch = space['n_batch']
#   33:     print('a modell hiperparaméterei: ', n_layer1, n_layer2, dropout_1, dropout_2, act, optim, n_batch)
#   34:     # 3 x 3 x [0-1]x[0-1] x 3 x 3 x 3  = hatalmas paraméter tér
#   35:
#   36:     # aktivacio: string -> valtozo
#   37:     if act == 'relu':
#   38:         activation = keras.layers.ReLU()
#   39:     elif act == 'leakyrelu':
#   40:         activation = keras.layers.LeakyReLU()
#   41:     elif act == 'swish':
#   42:         activation = Swish(beta=0.3)
#   43:
#   44:     model = Sequential()
#   45:     model.add(Dense(n_layer1, input_dim=784))
#   46:     model.add(activation)
#   47:     model.add(Dropout(dropout_1))
#   48:     model.add(Dense(n_layer2))
#   49:     model.add(activation)
#   50:     model.add(Dropout(dropout_2))
#   51:     model.add(Dense(10, activation='softmax'))
#   52:
#   53:     model.compile(optimizer=optim,
#   54:                   loss='categorical_crossentropy',
#   55:                   metrics=['accuracy'])
#   56:
#   57:     callbacks = [EarlyStopping(monitor='val_acc', patience=3, verbose=0)]
#   58:
#   59:     result = model.fit(x_train, y_train,
#   60:               batch_size=n_batch,
#   61:               epochs=100,
#   62:               verbose=2,
#   63:               validation_data=(x_test, y_test),
#   64:               callbacks=callbacks,
#   65:               shuffle=True)
#   66:
#   67:
#   68:     # az epoch-ok közül a legnagyobb val_acc elmentése
#   69:     best_val_acc = np.amax(result.history['val_acc'])
#   70:     print('legjobb val_acc:', best_val_acc)
#   71:
#   72:     # log kiírása: háló struktúra, és az eredmény
#   73:     with open('hyperas-fashionmnist-log.csv', 'a') as csv_file:
#   74:       csv_file.write(str(n_layer1) + ';')
#   75:       csv_file.write(str(n_layer2) + ';')
#   76:       csv_file.write(str(dropout_1) + ';')
#   77:       csv_file.write(str(dropout_2) + ';')
#   78:       csv_file.write(str(act) + ';')
#   79:       csv_file.write(str(optim) + ';')
#   80:       csv_file.write(str(n_batch) + ';')
#   81:       csv_file.write(str(best_val_acc) + '\n')
#   82:
#   83:
#   84:     # negatív val_acc, mert a hyperopt csomag mindig minimalizál
#   85:     return {'loss': -best_val_acc, 'status': STATUS_OK, 'model': model}
#   86:
# a modell hiperparaméterei:
# 128
# 256
# 0.30543815464061785
# 0.3685849187307607
# swish
# sgd
# 256
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
#  - 2s - loss: 1.9633 - acc: 0.3713 - val_loss: 1.5876 - val_acc: 0.5993
#
# Epoch 2/100
#  - 1s - loss: 1.3772 - acc: 0.5695 - val_loss: 1.1389 - val_acc: 0.6469
#
# Epoch 3/100
#  - 1s - loss: 1.0973 - acc: 0.6255 - val_loss: 0.9550 - val_acc: 0.6799
#
# Epoch 4/100
#  - 1s - loss: 0.9659 - acc: 0.6618 - val_loss: 0.8621 - val_acc: 0.7027
#
# Epoch 5/100
#  - 1s - loss: 0.8878 - acc: 0.6844 - val_loss: 0.8049 - val_acc: 0.7195
#
# Epoch 6/100
#  - 1s - loss: 0.8349 - acc: 0.7035 - val_loss: 0.7640 - val_acc: 0.7308
#
# Epoch 7/100
#  - 1s - loss: 0.7956 - acc: 0.7188 - val_loss: 0.7340 - val_acc: 0.7410
#
# Epoch 8/100
#  - 1s - loss: 0.7645 - acc: 0.7322 - val_loss: 0.7089 - val_acc: 0.7514
#
# Epoch 9/100
#  - 1s - loss: 0.7367 - acc: 0.7404 - val_loss: 0.6879 - val_acc: 0.7582
#
# Epoch 10/100
#  - 1s - loss: 0.7134 - acc: 0.7488 - val_loss: 0.6693 - val_acc: 0.7683
#
# Epoch 11/100
#  - 1s - loss: 0.6971 - acc: 0.7565 - val_loss: 0.6533 - val_acc: 0.7706
#
# Epoch 12/100
#  - 1s - loss: 0.6794 - acc: 0.7624 - val_loss: 0.6402 - val_acc: 0.7768
#
# Epoch 13/100
#  - 1s - loss: 0.6685 - acc: 0.7670 - val_loss: 0.6283 - val_acc: 0.7793
#
# Epoch 14/100
#  - 1s - loss: 0.6518 - acc: 0.7730 - val_loss: 0.6173 - val_acc: 0.7864
#
# Epoch 15/100
#  - 1s - loss: 0.6426 - acc: 0.7775 - val_loss: 0.6078 - val_acc: 0.7878
#
# Epoch 16/100
#  - 1s - loss: 0.6295 - acc: 0.7818 - val_loss: 0.5987 - val_acc: 0.7916
#
# Epoch 17/100
#  - 1s - loss: 0.6200 - acc: 0.7849 - val_loss: 0.5902 - val_acc: 0.7945
#
# Epoch 18/100
#  - 1s - loss: 0.6129 - acc: 0.7872 - val_loss: 0.5832 - val_acc: 0.7970
#
# Epoch 19/100
#  - 1s - loss: 0.6017 - acc: 0.7913 - val_loss: 0.5763 - val_acc: 0.7990
#
# Epoch 20/100
#  - 1s - loss: 0.5933 - acc: 0.7943 - val_loss: 0.5698 - val_acc: 0.8022
#
# Epoch 21/100
#  - 1s - loss: 0.5887 - acc: 0.7955 - val_loss: 0.5642 - val_acc: 0.8031
#
# Epoch 22/100
#  - 1s - loss: 0.5800 - acc: 0.7991 - val_loss: 0.5591 - val_acc: 0.8054
#
# Epoch 23/100
#  - 1s - loss: 0.5740 - acc: 0.8019 - val_loss: 0.5539 - val_acc: 0.8061
#
# Epoch 24/100
#  - 1s - loss: 0.5686 - acc: 0.8021 - val_loss: 0.5498 - val_acc: 0.8074
#
# Epoch 25/100
#  - 1s - loss: 0.5622 - acc: 0.8049 - val_loss: 0.5457 - val_acc: 0.8093
#
# Epoch 26/100
#  - 1s - loss: 0.5593 - acc: 0.8064 - val_loss: 0.5412 - val_acc: 0.8092
#
# Epoch 27/100
#  - 1s - loss: 0.5551 - acc: 0.8066 - val_loss: 0.5372 - val_acc: 0.8108
#
# Epoch 28/100
#  - 1s - loss: 0.5502 - acc: 0.8086 - val_loss: 0.5347 - val_acc: 0.8098
#
# Epoch 29/100
#  - 1s - loss: 0.5473 - acc: 0.8090 - val_loss: 0.5317 - val_acc: 0.8124
#
# Epoch 30/100
#  - 1s - loss: 0.5421 - acc: 0.8112 - val_loss: 0.5283 - val_acc: 0.8131
#
# Epoch 31/100
#  - 1s - loss: 0.5387 - acc: 0.8120 - val_loss: 0.5252 - val_acc: 0.8131
#
# Epoch 32/100
#  - 1s - loss: 0.5343 - acc: 0.8140 - val_loss: 0.5221 - val_acc: 0.8145
#
# Epoch 33/100
#  - 1s - loss: 0.5321 - acc: 0.8156 - val_loss: 0.5198 - val_acc: 0.8145
#
# Epoch 34/100
#  - 1s - loss: 0.5292 - acc: 0.8151 - val_loss: 0.5172 - val_acc: 0.8170
#
# Epoch 35/100
#  - 1s - loss: 0.5256 - acc: 0.8172 - val_loss: 0.5146 - val_acc: 0.8182
#
# Epoch 36/100
#  - 1s - loss: 0.5233 - acc: 0.8175 - val_loss: 0.5131 - val_acc: 0.8163
#
# Epoch 37/100
#  - 1s - loss: 0.5200 - acc: 0.8191 - val_loss: 0.5107 - val_acc: 0.8168
#
# Epoch 38/100
#  - 1s - loss: 0.5172 - acc: 0.8192 - val_loss: 0.5085 - val_acc: 0.8180
#
# legjobb val_acc:
# 0.8182
# a modell hiperparaméterei:
# 256
# 512
# 0.48850025868977437
# 0.41833334235579095
# swish
# rmsprop
# 64
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
#  - 5s - loss: 0.6302 - acc: 0.7775 - val_loss: 0.6523 - val_acc: 0.7683
#
# Epoch 2/100
#  - 5s - loss: 0.5035 - acc: 0.8213 - val_loss: 0.5113 - val_acc: 0.8154
#
# Epoch 3/100
#  - 5s - loss: 0.4670 - acc: 0.8339 - val_loss: 0.4391 - val_acc: 0.8460
#
# Epoch 4/100
#  - 5s - loss: 0.4438 - acc: 0.8390 - val_loss: 0.4797 - val_acc: 0.8314
#
# Epoch 5/100
#  - 5s - loss: 0.4267 - acc: 0.8463 - val_loss: 0.4393 - val_acc: 0.8370
#
# Epoch 6/100
#  - 5s - loss: 0.4184 - acc: 0.8506 - val_loss: 0.4114 - val_acc: 0.8555
#
# Epoch 7/100
#  - 5s - loss: 0.4102 - acc: 0.8531 - val_loss: 0.4160 - val_acc: 0.8516
#
# Epoch 8/100
#  - 5s - loss: 0.4015 - acc: 0.8572 - val_loss: 0.3849 - val_acc: 0.8627
#
# Epoch 9/100
#  - 5s - loss: 0.3953 - acc: 0.8593 - val_loss: 0.3862 - val_acc: 0.8644
#
# Epoch 10/100
#  - 5s - loss: 0.3913 - acc: 0.8617 - val_loss: 0.3841 - val_acc: 0.8619
#
# Epoch 11/100
#  - 5s - loss: 0.3827 - acc: 0.8643 - val_loss: 0.3991 - val_acc: 0.8640
#
# Epoch 12/100
#  - 5s - loss: 0.3810 - acc: 0.8662 - val_loss: 0.3661 - val_acc: 0.8733
#
# Epoch 13/100
#  - 5s - loss: 0.3796 - acc: 0.8662 - val_loss: 0.3778 - val_acc: 0.8655
#
# Epoch 14/100
#  - 5s - loss: 0.3761 - acc: 0.8663 - val_loss: 0.3939 - val_acc: 0.8681
#
# Epoch 15/100
#  - 5s - loss: 0.3710 - acc: 0.8694 - val_loss: 0.3843 - val_acc: 0.8691
#
# legjobb val_acc:
# 0.8733
# a modell hiperparaméterei:
# 512
# 512
# 0.19749681333133445
# 0.48790925917284717
# relu
# adam
# 64
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
#  - 7s - loss: 0.5312 - acc: 0.8064 - val_loss: 0.4266 - val_acc: 0.8439
#
# Epoch 2/100
#  - 6s - loss: 0.4024 - acc: 0.8535 - val_loss: 0.3843 - val_acc: 0.8631
#
# Epoch 3/100
#  - 6s - loss: 0.3652 - acc: 0.8662 - val_loss: 0.3606 - val_acc: 0.8686
#
# Epoch 4/100
#  - 6s - loss: 0.3467 - acc: 0.8711 - val_loss: 0.3553 - val_acc: 0.8707
#
# Epoch 5/100
#  - 6s - loss: 0.3329 - acc: 0.8775 - val_loss: 0.3595 - val_acc: 0.8716
#
# Epoch 6/100
#  - 6s - loss: 0.3241 - acc: 0.8813 - val_loss: 0.3291 - val_acc: 0.8808
#
# Epoch 7/100
#  - 6s - loss: 0.3120 - acc: 0.8833 - val_loss: 0.3426 - val_acc: 0.8799
#
# Epoch 8/100
#  - 6s - loss: 0.3019 - acc: 0.8867 - val_loss: 0.3319 - val_acc: 0.8831
#
# Epoch 9/100
#  - 6s - loss: 0.2926 - acc: 0.8905 - val_loss: 0.3235 - val_acc: 0.8836
#
# Epoch 10/100
#  - 6s - loss: 0.2861 - acc: 0.8940 - val_loss: 0.3532 - val_acc: 0.8756
#
# Epoch 11/100
#  - 6s - loss: 0.2793 - acc: 0.8958 - val_loss: 0.3276 - val_acc: 0.8792
#
# Epoch 12/100
#  - 6s - loss: 0.2739 - acc: 0.8972 - val_loss: 0.3218 - val_acc: 0.8875
#
# Epoch 13/100
#  - 6s - loss: 0.2755 - acc: 0.8976 - val_loss: 0.3344 - val_acc: 0.8829
#
# Epoch 14/100
#  - 6s - loss: 0.2641 - acc: 0.9009 - val_loss: 0.3268 - val_acc: 0.8831
#
# Epoch 15/100
#  - 6s - loss: 0.2611 - acc: 0.9014 - val_loss: 0.3427 - val_acc: 0.8819
#
# legjobb val_acc:
# 0.8875
# a modell hiperparaméterei:
# 256
# 256
# 0.05864877623022119
# 0.42221220495036493
# relu
# adam
# 128
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
#  - 3s - loss: 0.5610 - acc: 0.7999 - val_loss: 0.4196 - val_acc: 0.8461
#
# Epoch 2/100
#  - 3s - loss: 0.3919 - acc: 0.8575 - val_loss: 0.3820 - val_acc: 0.8608
#
# Epoch 3/100
#  - 3s - loss: 0.3504 - acc: 0.8718 - val_loss: 0.3762 - val_acc: 0.8620
#
# Epoch 4/100
#  - 3s - loss: 0.3303 - acc: 0.8793 - val_loss: 0.3697 - val_acc: 0.8669
#
# Epoch 5/100
#  - 3s - loss: 0.3138 - acc: 0.8844 - val_loss: 0.3531 - val_acc: 0.8721
#
# Epoch 6/100
#  - 3s - loss: 0.2996 - acc: 0.8899 - val_loss: 0.3343 - val_acc: 0.8792
#
# Epoch 7/100
#  - 3s - loss: 0.2876 - acc: 0.8938 - val_loss: 0.3355 - val_acc: 0.8805
#
# Epoch 8/100
#  - 3s - loss: 0.2777 - acc: 0.8979 - val_loss: 0.3317 - val_acc: 0.8809
#
# Epoch 9/100
#  - 3s - loss: 0.2652 - acc: 0.9016 - val_loss: 0.3237 - val_acc: 0.8834
#
# Epoch 10/100
#  - 3s - loss: 0.2577 - acc: 0.9030 - val_loss: 0.3330 - val_acc: 0.8829
#
# Epoch 11/100
#  - 3s - loss: 0.2512 - acc: 0.9056 - val_loss: 0.3212 - val_acc: 0.8849
#
# Epoch 12/100
#  - 3s - loss: 0.2452 - acc: 0.9080 - val_loss: 0.3472 - val_acc: 0.8800
#
# Epoch 13/100
#  - 3s - loss: 0.2389 - acc: 0.9093 - val_loss: 0.3238 - val_acc: 0.8868
#
# Epoch 14/100
#  - 3s - loss: 0.2313 - acc: 0.9118 - val_loss: 0.3208 - val_acc: 0.8885
#
# Epoch 15/100
#  - 3s - loss: 0.2264 - acc: 0.9138 - val_loss: 0.3235 - val_acc: 0.8878
#
# Epoch 16/100
#  - 3s - loss: 0.2199 - acc: 0.9161 - val_loss: 0.3282 - val_acc: 0.8872
#
# Epoch 17/100
#  - 3s - loss: 0.2160 - acc: 0.9178 - val_loss: 0.3374 - val_acc: 0.8859
#
# legjobb val_acc:
# 0.8885
# a modell hiperparaméterei:
# 512
# 512
# 0.47663695683601787
# 0.06874772122693129
# relu
# rmsprop
# 128
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/100
#  - 4s - loss: 0.5962 - acc: 0.7828 - val_loss: 0.4490 - val_acc: 0.8378
#
# Epoch 2/100
#  - 3s - loss: 0.4396 - acc: 0.8399 - val_loss: 0.3987 - val_acc: 0.8640
#
# Epoch 3/100
#  - 3s - loss: 0.4083 - acc: 0.8520 - val_loss: 0.4075 - val_acc: 0.8548
#
# Epoch 4/100
#  - 3s - loss: 0.3901 - acc: 0.8582 - val_loss: 0.3902 - val_acc: 0.8606
#
# Epoch 5/100
#  - 3s - loss: 0.3774 - acc: 0.8651 - val_loss: 0.3786 - val_acc: 0.8631
#
# legjobb val_acc:
# 0.864
# 100%|██████████| 5/5 [04:38<00:00, 47.64s/it, best loss: -0.8885]

# %%
x_train, y_train, x_test, y_test = data()
print("legjobb modell kiértékelése:")
print(best_model.evaluate(x_test, y_test))
print("legjobb hiperparaméterek:")
# a best_run az indexeket adja vissza,
# azaz pl: 
# n_layer1 = {{choice([128, 256, 512])}}
# és 
# 'n_layer1': 1
# -> a legjobb n_layer1 érték a 256
print(best_run)
# Out:
# legjobb modell kiértékelése:
# 10000/10000 [==============================] - 1s 54us/step
# [0.3374348077893257, 0.8859]
# legjobb hiperparaméterek:
# {'act': 0, 'dropout_1': 0.05864877623022119, 'dropout_1_1': 0.42221220495036493, 'n_batch': 1, 'n_layer1': 1, 'n_layer1_1': 1, 'optim': 1}

# %%
# ugyan 5 futtatás nagyon kevés,
# de sikerült jobb eredményt elérni, mint a fenti egyszerű hálózattal
# (88.59% vs. 87.81%)

# %%
import pandas
df = pandas.read_csv('hyperas-fashionmnist-log.csv', delimiter=';')
df.sort_values(by=['best_val_acc'], ascending=False)
# Out:
#    n_layer1  n_layer2  dropout_1  ...    optim n_batch best_val_acc
# 3       256       256   0.058649  ...     adam     128       0.8885
# 2       512       512   0.197497  ...     adam      64       0.8875
# 1       256       512   0.488500  ...  rmsprop      64       0.8733
# 4       512       512   0.476637  ...  rmsprop     128       0.8640
# 0       128       256   0.305438  ...      sgd     256       0.8182
#
# [5 rows x 8 columns]

# %%
# a valóságban inkább ~1000 futtatás érdemes
# -> itt most megvizsgáljuk egy korábbi hiperopt eredményét

# %%
# a következő részben betöltjük a nagy csv fájlt (~1000 tanítás eredménye), majd
# adat vizualizáció, azaz hogyan függ a val_acc a háló egyes paramétereitől?

# %%
import pandas
hyperas_log = pandas.read_csv('hyperas-fashionmnist-log_829.csv', delimiter=';')

# %%
# nézzük meg a 10 legjobb hálót!
hyperas_best10 = hyperas_log.sort_values(by=['best_val_acc'], ascending=False).head(n=10)
hyperas_best10
# Out:
#      n_layer1  n_layer2  dropout_1  ...    optim n_batch best_val_acc
# 613       256       256   0.057500  ...     adam     128       0.9021
# 703       256       256   0.055486  ...     adam     128       0.8999
# 599       256       256   0.093041  ...     adam     128       0.8989
# 590       256       256   0.186405  ...     adam     128       0.8986
# 520       256       256   0.219907  ...     adam     256       0.8984
# 820       256       256   0.074415  ...     adam     128       0.8982
# 793       256       256   0.027088  ...     adam     128       0.8982
# 192       512       256   0.055206  ...  rmsprop     256       0.8982
# 539       256       256   0.161702  ...     adam     128       0.8981
# 688       256       256   0.068579  ...     adam     128       0.8980
#
# [10 rows x 8 columns]

# %%
# és nézzük meg a 10 legrosszabb hálót is!
hyperas_worst10 = hyperas_log.sort_values(by=['best_val_acc'], ascending=False).tail(n=10)
hyperas_worst10
# Out:
#      n_layer1  n_layer2  dropout_1  ...  optim n_batch best_val_acc
# 645       256       512   0.079881  ...    sgd     128       0.8374
# 174       256       128   0.413120  ...    sgd     128       0.8373
# 110       128       256   0.487781  ...    sgd      64       0.8370
# 188       256       128   0.317484  ...    sgd     128       0.8369
# 75        128       256   0.261419  ...    sgd      64       0.8364
# 103       256       256   0.330860  ...    sgd     256       0.8353
# 209       128       256   0.416123  ...    sgd     128       0.8352
# 675       256       256   0.093233  ...    sgd     128       0.8350
# 0         128       256   0.305438  ...    sgd     256       0.8310
# 86        128       256   0.420083  ...    sgd     256       0.8303
#
# [10 rows x 8 columns]

# %%
# de vajon hogy függnek össze az egyes hiperparaméterek a val_acc-cal?
import matplotlib.pyplot as plt

# %%
# összes adat kékkel,
# legjobb 10 hálózat pirossal
for hyperparam in ['n_layer1', 'n_layer2', 'dropout_1', 'dropout_2', 'n_batch']:
  ax1 = hyperas_log.plot(kind='scatter', x=hyperparam, y='best_val_acc')
  hyperas_best10.plot(kind='scatter', x=hyperparam, y='best_val_acc', color='red', ax=ax1)
  hyperas_worst10.plot(kind='scatter', x=hyperparam, y='best_val_acc', color='yellow', ax=ax1)

# %%
# act, optim: kategorikus változók
# (https://github.com/pandas-dev/pandas/issues/18755)
plt.scatter(hyperas_log.act, hyperas_log.best_val_acc)
plt.scatter(hyperas_best10.act, hyperas_best10.best_val_acc, color='red')
plt.scatter(hyperas_worst10.act, hyperas_worst10.best_val_acc, color='yellow')
plt.show()

plt.scatter(hyperas_log.optim, hyperas_log.best_val_acc)
plt.scatter(hyperas_best10.optim, hyperas_best10.best_val_acc, color='red')
plt.scatter(hyperas_worst10.optim, hyperas_worst10.best_val_acc, color='yellow')
plt.show()

# %%
# de vajon hogy függ össze az egyes hiperparaméterek kombinációja a val_acc-cal?
# ábrázoljuk seaborn-nal

import seaborn as sns

# %%
max_val_acc = hyperas_log.groupby(['n_batch', 'optim']).max()
max_val_acc = max_val_acc.unstack()[['best_val_acc']]
sns.heatmap(max_val_acc.best_val_acc, annot=True, fmt='.4g');

# bug: seaborn cuts off borders, https://github.com/mwaskom/seaborn/issues/1773
b, t = plt.ylim() # discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values
# Out:
# (3.0, 0.0)

# %%
# de vajon hogy függ össze az egyes hiperparaméterek kombinációja a val_acc-cal?
# ábrázoljuk matplotlib / scatter3d-vel

# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D

# %%
# n_layer1 / n_layer2
fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111, projection='3d')
p = ax.scatter3D(hyperas_log.n_layer1, hyperas_log.n_layer2, hyperas_log.best_val_acc, c=hyperas_log.best_val_acc)
ax.set_xlabel('n_layer1')
ax.set_ylabel('n_layer2')
ax.set_zlabel('best_val_acc')
fig.colorbar(p)
plt.show()

# %%
# dropout_1 / dropout_2
fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111, projection='3d')
p = ax.scatter3D(hyperas_log.dropout_1, hyperas_log.dropout_2, hyperas_log.best_val_acc, c=hyperas_log.best_val_acc)
ax.set_xlabel('dropout_1')
ax.set_ylabel('dropout_1')
ax.set_zlabel('best_val_acc')
fig.colorbar(p)
plt.show()

# %%
# n_batch / dropout_1
fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111, projection='3d')
p = ax.scatter3D(hyperas_log.n_batch, hyperas_log.dropout_1, hyperas_log.best_val_acc, c=hyperas_log.best_val_acc)
ax.set_xlabel('n_batch')
ax.set_ylabel('dropout_1')
ax.set_zlabel('best_val_acc')
fig.colorbar(p)
plt.show()

# %%
# a fenti logok és ábrák alapján úgy tűnik, hogy a nyerő kombináció:
# - n_layer1=256, n_layer2=256
# - dropout alacsony
# - act=relu
# - optim=adam
# - n_batch=128

# %%
# VÉGE.
# konklúzió: hyperas-szal kb 5-10%-nyi pontosságot sikerült nyerni
# de: nagyobb háló / komplexebb probléma esetén lényegesen többet is lehet javítani
